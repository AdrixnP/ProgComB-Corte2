# %%
deformidad(metodo)
class Humanos:
  def __init__(self,ojos,cabello,boca,orejas,nariz,dientes,lengua,pestanas,brazos,piernas,peso, altura,sexo,cuello,pie,rodilla,hombro,cabeza,nombre):
    self.ojos=ojos
    self.cabello=cabello
    self.boca=boca
    self.orejas=orejas
    self.nariz=nariz
    self.dientes=dientes
    self.lengua=lengua
    self.pestanas=pestanas
    self.brazos=brazos
    self.piernas=piernas
    self.peso=peso
    self.altura=altura
    self.sexo=sexo
    self.cuello=cuello
    self.pie=pie
    self.rodilla=rodilla
    self.hombro=hombro
    self.cabeza=cabeza
    self.nombre=nombre
  def moverse(self,velocidad):
    if velocidad==0:
      return f"{self.nombre} está en estado de reposo"
    elif velocidad>0 and velocidad >=3:
      return f"{self.nombre} está caminando"
    elif velocidad>3 and velocidad >=5:
      return f"{self.nombre} está caminando rapido"
    elif velocidad>5 and velocidad >=8:
      return f"{self.nombre} está trotanto"
    elif velocidad>8 and velocidad >=15:
      return f"{self.nombre} está corriendo"
    elif velocidad>15 and velocidad >=200:
      return f"{self.nombre} está en un vehiculo"
    elif velocidad>200:
      return f"{self.nombre} está volando"

nombre=str(input("Ingresa el nombre: "))
velocidad=int(input("Ingresa la velocidad de movimiento: "))
humano1=Humanos(nombre)
vel=humano1.movilizarse(velocidad)

# %%
class Sayayin:
  def __init__(self,ojos,cabello,boca,orejas,nariz,dientes,lengua,pestanas,brazos,piernas,peso, altura,sexo,cuello,pie,rodilla,codo,cabeza,nombre):
    self.ojos=ojos
    self.cojos="negros"
    self.cabello=cabello
    self.boca=boca
    self.orejas=orejas
    self.nariz=nariz
    self.dientes=dientes
    self.lengua=lengua
    self.pestanas=pestanas
    self.brazos=brazos
    self.piernas=piernas
    self.peso=peso
    self.altura=altura
    self.sexo=sexo
    self.cuello=cuello
    self.pie=pie
    self.rodilla=rodilla
    self.codo=codo

    self.cabeza=cabeza

    self.nombre=nombre
    self.cola_de_mono=True
  def movilizarse(self,velocidad):
    if velocidad==0:
      return f"{self.nombre} está en estado de reposo"
    elif velocidad>0 and velocidad >=3:
      return f"{self.nombre} está caminando"
    elif velocidad>3 and velocidad >=5:
      return f"{self.nombre} está caminando rapido"
    elif velocidad>5 and velocidad >=8:
      return f"{self.nombre} está trotanto"
    elif velocidad>8 and velocidad >=20:
      return f"{self.nombre} está corriendo"
    elif velocidad>20:
      return f"{self.nombre} está volando"
  
  def trabajos(self,trabajo):
    tr=["Esclavo","Mercenario","Pilotos","Luchadores"]
    if tr[trabajo] in trabajo:
      if trabajo==0:
        print(self.nombre,"esta",tr[trabajo])
      else:
        print(self.nombre,"es",tr[trabajo])

  def luna(self,luna):
    if luna and self.cola_de_mono:
      print(self.nombre,"se va a transformar en mono gigante")
